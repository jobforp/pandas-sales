# %%
import pandas as pd
names1=['name', 'sex', 'births']
names = pd.read_csv('/home/ant/pandas/names.csv.gz',compression='gzip')
names.head()
# Out:
#    Unnamed: 0       name sex  births  year
# 0           0       Mary   F    7065  1880
# 1           1       Anna   F    2604  1880
# 2           2       Emma   F    2003  1880
# 3           3  Elizabeth   F    1939  1880
# 4           4     Minnie   F    1746  1880
#
# [5 rows x 5 columns]

# %%
names.count()
# Out:
# Unnamed: 0    1725188
# name          1725188
# sex           1725188
# births        1725188
# year          1725188
# dtype: int64

# %%
ant = names[((names.sex=='M') & (names.name=='Anthony'))]
ant.tail()
# Out:
#          Unnamed: 0     name sex  births  year
# 1573290     1573290  Anthony   M   19599  2007
# 1608096     1608096  Anthony   M   18365  2008
# 1642848     1642848  Anthony   M   16266  2009
# 1677137     1677137  Anthony   M   15448  2010
# 1710886     1710886  Anthony   M   14222  2011

# %%
ant2 = ant.set_index(ant.year)
ant2.tail()
# Out:
#       Unnamed: 0     name sex  births  year
# year
# 2007     1573290  Anthony   M   19599  2007
# 2008     1608096  Anthony   M   18365  2008
# 2009     1642848  Anthony   M   16266  2009
# 2010     1677137  Anthony   M   15448  2010
# 2011     1710886  Anthony   M   14222  2011

# %%
ant2.births.sum()
# Out:
# 1365993

# %%
#import pandas as pd
#names = pd.read_csv('/home/ant/Downloads/ml/names.csv')
total_births =names.pivot_table('births', rows='year', cols='sex', aggfunc=sum)
total_births.plot()

# %%
total_births.tail()
# Out:
# sex         F        M
# year
# 2007  1918618  2071178
# 2008  1886109  2035075
# 2009  1831382  1977632
# 2010  1770632  1911572
# 2011  1750078  1889557

# %%
def add_prop(group):
        # Integer division floors
    births = group.births.astype(float)

    group['prop'] = births / births.sum()
    return group

names = names.groupby(['year', 'sex']).apply(add_prop)

# %%
names.head()
# Out:
#    Unnamed: 0       name sex  births  year      prop
# 0           0       Mary   F    7065  1880  0.077643
# 1           1       Anna   F    2604  1880  0.028618
# 2           2       Emma   F    2003  1880  0.022013
# 3           3  Elizabeth   F    1939  1880  0.021309
# 4           4     Minnie   F    1746  1880  0.019188

# %%
def get_top1000(group):
    return group.sort_index(by='births', ascending=False)[:1000]


grouped = names.groupby(['year', 'sex'])
top1000 = grouped.apply(get_top1000)
top1000.head()
# Out:
#             Unnamed: 0       name sex  births  year      prop
# year sex
# 1880 F   0           0       Mary   F    7065  1880  0.077643
#          1           1       Anna   F    2604  1880  0.028618
#          2           2       Emma   F    2003  1880  0.022013
#          3           3  Elizabeth   F    1939  1880  0.021309
#          4           4     Minnie   F    1746  1880  0.019188

# %%
boys = top1000[top1000.sex=='M']
girls = top1000[top1000.sex=='F']
boys.head()
# Out:
#               Unnamed: 0     name sex  births  year      prop
# year sex
# 1880 M   942         942     John   M    9655  1880  0.087383
#          943         943  William   M    9532  1880  0.086269
#          944         944    James   M    5927  1880  0.053642
#          945         945  Charles   M    5348  1880  0.048402
#          946         946   George   M    5126  1880  0.046393

# %%
total_births = top1000.pivot_table('births', rows='year', cols='name', aggfunc=sum)
total_births.head()
total_births
subset = total_births[['John', 'Harry', 'Mary', 'Marilyn']]
subset.plot(subplots=True, figsize=(12, 10), grid=False,title="test")
# Out:
# array([<matplotlib.axes.AxesSubplot object at 0x176fa5d0>,
# ...
#        <matplotlib.axes.AxesSubplot object at 0x221db410>], dtype=object)

# %%
q = names[((names.name =="Mary") | (names.name=="Anthony"))]

# %%
q.tail()
# Out:
#          Unnamed: 0     name sex  births  year
# 1662449     1662449  Anthony   F      27  2010
# 1677137     1677137  Anthony   M   15448  2010
# 1691468     1691468     Mary   F    2692  2011
# 1696888     1696888  Anthony   F      24  2011
# 1710886     1710886  Anthony   M   14222  2011

# %%
q.name.value_counts()
# Out:
# Mary       260
# Anthony    236
# dtype: int64
